# %%
pip install transformers torch
# Out:
# Requirement already satisfied: transformers in c:\users\saipa\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: torch in c:\users\saipa\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (0.9.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\saipa\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\saipa\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\saipa\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\saipa\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\saipa\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\saipa\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.12.2)
# Requirement already satisfied: anyio in c:\users\saipa\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.7.0)
# Requirement already satisfied: certifi in c:\users\saipa\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\saipa\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\saipa\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\saipa\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\saipa\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\saipa\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\saipa\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\saipa\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\saipa\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\saipa\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\saipa\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saipa\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\saipa\anaconda3\lib\site-packages (from typer->transformers) (8.1.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. Correct Imports
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import torch

# 2. Model Loading (Blenderbot is Seq2Seq)
model_name = "facebook/blenderbot-400M-distill"

# USE AutoModelForSeq2SeqLM for Blenderbot
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin:   0%|          | 0.00/730M [00:00<?, ?B/s]
# C:\Users\saipa\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\saipa\.cache\huggingface\hub\models--facebook--blenderbot-400M-distill. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading weights:   0%|          | 0/355 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# BlenderbotForConditionalGeneration(
#   (model): BlenderbotModel(
#     (shared): BlenderbotScaledWordEmbedding(8008, 1280, padding_idx=0)
#     (encoder): BlenderbotEncoder(
#       (embed_tokens): BlenderbotScaledWordEmbedding(8008, 1280, padding_idx=0)
#       (embed_positions): BlenderbotLearnedPositionalEmbedding(128, 1280)
#       (layers): ModuleList(
#         (0-1): 2 x BlenderbotEncoderLayer(
#           (self_attn): BlenderbotAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#           (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#           (final_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BlenderbotDecoder(
#       (embed_tokens): BlenderbotScaledWordEmbedding(8008, 1280, padding_idx=0)
#       (embed_positions): BlenderbotLearnedPositionalEmbedding(128, 1280)
#       (layers): ModuleList(
#         (0-11): 12 x BlenderbotDecoderLayer(
#           (self_attn): BlenderbotAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BlenderbotAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#           (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#           (final_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1280, out_features=8008, bias=False)
# )

# %%
# 1. Model Loading 
model_name = "facebook/blenderbot-400M-distill"   
tokenizer = AutoTokenizer.from_pretrained(model_name)

# FIX: Use AutoModelForSeq2SeqLM instead of AutoModelForCausalLM
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def run_chatbot():
    print("🤖 Chatbot: Hello! I am your AI assistant. How can I help you today?")
    print("(Type 'exit' or 'quit' to stop the conversation)\n")
    
    while True:
        user_input = input("You: ").strip()

        if not user_input:
            continue
        
        if user_input.lower() in ['exit', 'quit']:
            # Make sure we print the last user input before quitting
            print(f"You: {user_input}")
            print("🤖 Chatbot: Goodbye! Have a great day.")
            break
        
        # Encode input
        inputs = tokenizer(user_input, return_tensors="pt").to(device)

        # Generate response
        reply_ids = model.generate(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            max_length=100
        )
        
        # Decode response
        response = tokenizer.decode(reply_ids[0], skip_special_tokens=True)
        
        # Print output
        print(f"You: {user_input}")
        print(f" Chatbot: {response}\n")

if __name__ == "__main__":
    run_chatbot()
# Out:
# Loading weights:   0%|          | 0/355 [00:00<?, ?it/s]
# 🤖 Chatbot: Hello! I am your AI assistant. How can I help you today?
# (Type 'exit' or 'quit' to stop the conversation)
# You:  Hello
# You: Hello
#  Chatbot:  Hi, how are you? I just got back from walking my dog. Do you have any pets?
# You:  what is AI?
# You: what is AI?
#  Chatbot:  An AI is a computer that is capable of performing many tasks for a person.
# You:  what is machine learning?
# You: what is machine learning?
#  Chatbot:  Machine learning is the process of learning how to do something with a machine. It's a lot of fun!
# You:  exit
# You: exit
# 🤖 Chatbot: Goodbye! Have a great day.
